# %%
import requests

# %%
# Для скачивания данных по

offset_ = 1
limit_ = 5393
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
objects_data = res.json()

# %%
objects_data.get('data').get('total')
# Out:
# 10786

# %%
objects_data.get('data').get('list')
# Out:
# [{'hobjId': 39024,
#   'objId': 13383,
#   'developer': {'devId': 306,
#    'shortName': '2МЕН ГРУПП',
#    'fullName': '2МЕН ГРУПП',
#    'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'companyGroup': 5776,
#    'devInn': '7701651356'},
#   'rpdRegionCd': 72,
#   'objAddr': 'г Тюмень',
#   'objFloorMin': 4,
#   'objFloorMax': 20,
#   'objElemLivingCnt': 68,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 6296.55,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 57.1519,
#   'longitude': 65.5536,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '72-000095',
#   'pdId': 28105,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'hobjId': 37165,
#   'objId': 13398,
#   'developer': {'devId': 306,
#    'shortName': '2МЕН ГРУПП',
#    'fullName': '2МЕН ГРУПП',
# ...

# %%
objects_data.get('data').get('list')[0]
# Out:
# {'hobjId': 39024,
#  'objId': 13383,
#  'developer': {'devId': 306,
#   'shortName': '2МЕН ГРУПП',
#   'fullName': '2МЕН ГРУПП',
#   'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#   'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#   'companyGroup': 5776,
#   'devInn': '7701651356'},
#  'rpdRegionCd': 72,
#  'objAddr': 'г Тюмень',
#  'objFloorMin': 4,
#  'objFloorMax': 20,
#  'objElemLivingCnt': 68,
#  'objReady100PercDt': '2022-12-31',
#  'objSquareLiving': 6296.55,
#  'objCompensFundFlg': 1,
#  'objProblemFlg': 0,
#  'latitude': 57.1519,
#  'longitude': 65.5536,
#  'problemFlag': 'NONE',
#  'siteStatus': 'Строящиеся',
#  'objGuarantyEscrowFlg': 0,
#  'residentialBuildings': 1,
#  'rpdNum': '72-000095',
#  'pdId': 28105,
#  'buildType': 'Жилое',
#  'objStatus': 0}

# %%
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]
objids[:10]
# Out:
# [13383, 13398, 13397, 13399, 36912, 10891, 8809, 8810, 39176, 39175]

# %%
# Для скачивания данных по определенному объекту, нужно добавить его id в конец строки запроса
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/13383'

# %%
res = requests.get(url)
d = res.json()

# %%
import pandas as pd
from tqdm.auto import tqdm

# %%
d = []
for obj in tqdm(objids):
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{obj}'
    res = requests.get(url)
    d.append(res.json())
# Out:
#   0%|          | 0/5393 [00:00<?, ?it/s]

# %%
pd.json_normalize(d)
# Out:
#      errcode  data.id  data.hobjId  data.pdId  data.developer.devId  \
# 0          0    13383        39024      28105                   306
# 1          0    13398        37165      28141                   306
# 2          0    13397        37201      28141                   306
# 3          0    13399        34754      28141                   306
# 4          0    36912       117248     337586                 10296
# ...      ...      ...          ...        ...                   ...
# 5388       0    48479       129116     631241                 11148
# 5389       0    38275       118671     394428                 11148
# 5390       0    41005       121536     464674                 12121
# 5391       0    44687       125285     534878                 13419
# 5392       0    37489       117878     371615                  1893
#
#                 data.developer.devShortCleanNm  \
# 0                                   2МЕН ГРУПП
# 1                                   2МЕН ГРУПП
# ...

# %%
df_1 = pd.json_normalize(d)

# %%
df_1
# Out:
#      errcode  data.id  data.hobjId  data.pdId  data.developer.devId  \
# 0          0    13383        39024      28105                   306
# 1          0    13398        37165      28141                   306
# 2          0    13397        37201      28141                   306
# 3          0    13399        34754      28141                   306
# 4          0    36912       117248     337586                 10296
# ...      ...      ...          ...        ...                   ...
# 5388       0    48479       129116     631241                 11148
# 5389       0    38275       118671     394428                 11148
# 5390       0    41005       121536     464674                 12121
# 5391       0    44687       125285     534878                 13419
# 5392       0    37489       117878     371615                  1893
#
#                 data.developer.devShortCleanNm  \
# 0                                   2МЕН ГРУПП
# 1                                   2МЕН ГРУПП
# ...

# %%
offset_ = 5393
limit_ = 10786
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
objects_data = res.json()

# %%
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]
objids[:10]
# Out:
# [37489, 45136, 46642, 37398, 42027, 48484, 43820, 47155, 47157, 47156]

# %%
f = []
for obj in tqdm(objids):
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{obj}'
    res = requests.get(url)
    f.append(res.json())
# Out:
#   0%|          | 0/5393 [00:00<?, ?it/s]

# %%
df_2 = pd.json_normalize(f)

# %%
df_2
# Out:
#      errcode  data.id  data.hobjId  data.pdId  data.developer.devId  \
# 0          0    37489       117878     371615                  1893
# 1          0    45136       125736     557203                 13703
# 2          0    46642       127277     597525                  2324
# 3          0    37398       117784     380442                  8829
# 4          0    42027       122593     297055                  7570
# ...      ...      ...          ...        ...                   ...
# 5388       0    28071        19791      99284                  7344
# 5389       0    28070        19242      99487                  7344
# 5390       0    28073        19245      96446                  7344
# 5391       0    44447       125044     475093                  2538
# 5392       0    45321       125942     516648                  2912
#
#                 data.developer.devShortCleanNm  \
# 0     СЗ МОСКОВСКИЙ ТКАЦКО-ОТДЕЛОЧНЫЙ КОМБИНАТ
# 1                                  СЗ МОССТРОЙ
# ...

# %%
res_df = pd.concat([df_1, df_2], ignore_index = True)

# %%
res_df
# Out:
#       errcode  data.id  data.hobjId  data.pdId  data.developer.devId  \
# 0           0    13383        39024      28105                   306
# 1           0    13398        37165      28141                   306
# 2           0    13397        37201      28141                   306
# 3           0    13399        34754      28141                   306
# 4           0    36912       117248     337586                 10296
# ...       ...      ...          ...        ...                   ...
# 10781       0    28071        19791      99284                  7344
# 10782       0    28070        19242      99487                  7344
# 10783       0    28073        19245      96446                  7344
# 10784       0    44447       125044     475093                  2538
# 10785       0    45321       125942     516648                  2912
#
#       data.developer.devShortCleanNm data.developer.devShortNm  \
# 0                         2МЕН ГРУПП                2МЕН ГРУПП
# ...

# %%
res_df.to_excel(r'C:\Users\eugen\Desktop\Jupytier_Notebook\res_df_excel.xlsx')

# %%
res_df.to_pickle(r'C:\Users\eugen\Desktop\Jupytier_Notebook\res_df_pickle.pkl')

# %%
print(res_df.dtypes)
# Out:
# errcode                                         object
# data.id                                          int64
# data.hobjId                                      int64
# data.pdId                                        int64
# data.developer.devId                             int64
#                                                 ...
# data.developer.bankruptStage.bankruptLawUrl     object
# data.developer.orgBankruptMsgDttm               object
# data.airQualityIndexValue                      float64
# data.complexShortNm                             object
# data.greenAreaIndexValue                       float64
# Length: 111, dtype: object

# %%
import numpy as np
res_df = res_df.astype(np.str)
# Out:
# C:\Users\eugen\AppData\Local\Temp\ipykernel_10624\3273588237.py:2: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   res_df = res_df.astype(np.str)

# %%
import sqlite3
conn = sqlite3.connect('res_df_database')

# %%
res_df.to_sql('df', conn, if_exists='replace', index = False)
# Out:
# 10786

# %%
pd.read_sql('select * from df', conn)
# Out:
#       errcode data.id data.hobjId data.pdId data.developer.devId  \
# 0           0   13383       39024     28105                  306
# 1           0   13398       37165     28141                  306
# 2           0   13397       37201     28141                  306
# 3           0   13399       34754     28141                  306
# 4           0   36912      117248    337586                10296
# ...       ...     ...         ...       ...                  ...
# 10781       0   28071       19791     99284                 7344
# 10782       0   28070       19242     99487                 7344
# 10783       0   28073       19245     96446                 7344
# 10784       0   44447      125044    475093                 2538
# 10785       0   45321      125942    516648                 2912
#
#       data.developer.devShortCleanNm data.developer.devShortNm  \
# 0                         2МЕН ГРУПП                2МЕН ГРУПП
# ...
